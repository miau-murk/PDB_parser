# %%
from __future__ import print_function
from rdkit.Chem import AllChem
from rdkit import DataStructs
from rdkit import Chem
from rdkit import RDLogger
import subprocess
import time
import signal
from subprocess import Popen
import warnings
import shlex
import os

lg = RDLogger.logger()
lg.setLevel(RDLogger.ERROR)  # Only show errors, not warnings.

warnings.filterwarnings("ignore")

# %% [markdown]
# Create basic functions:

# %%
def replacement_v1(f1, f2, before, after): # name_input, name_output
    
    '''the function performs a topologically 
        identicalsubstitution in molecules'''
    
    cmd_pattern = ['replacement ', ' -i ', '', ' -o ', '', ' -before ' + before + ' -after ' + after + ' -all_atoms']
    cmd_pattern[2] = f1
    cmd_pattern[4] = f2
    cmd = ''.join(cmd_pattern)
    args = shlex.split(cmd)
    p = subprocess.Popen(args)
    result = p.communicate(timeout=5)[0]
    

def write_file(file_name, str_cont):
    
    '''the function writes a file with
        the specified extension'''
    
    ff = open(file_name, "w")
    ff.writelines(str_cont)
    ff.close()

def open_file_if_exists(filename):
    if os.path.exists(filename):
        with open(filename, 'rb') as file:
            return file.read()
    else:
        return None

# %% [markdown]
# It is also the generaly part of alghoritm. We are create help files and do bioisosterics replacement.

# %%
SMILES_cont = []
help_cont = []
file = open("Components-pub.sdf", "r")

with Chem.SDWriter('H_F_1.sdf') as SDFWr:
    for line in file:
        if line.strip() != '$$$$':
            help_cont.append(line)
        else:
            help_set = set()
            write_file("in.mol", help_cont)
            mol = Chem.MolFromMolFile("in.mol")

            if mol is not None:
                molecule_name = mol.GetProp('_Name')
                replacement_v1("in.mol", "out.sdf", "F", "H")

                if os.path.exists('out.sdf') == True:
                    inf = open('out.sdf', 'rb')
                    fsuppl = Chem.ForwardSDMolSupplier(inf)
                    for mol in fsuppl:
                        
                        if mol != None:
                            smi = Chem.MolToSmiles(mol)
                            help_set.add(smi)

                            SDFWr.write(mol)
                    if len(help_set) != 0:
                        SMILES_cont.append([help_set, molecule_name])
                    inf.close()
                    os.remove("out.sdf")
                else:
                    os.remove("in.mol")
            help_cont = []
            
file.close()
            
#os.remove("in.mol")
#print(SMILES_cont)
# Out:
# [12:06:29] Explicit valence for atom # 15 N, 4, is greater than permitted
# [12:06:35] ERROR: Cannot process coordinates on line 6
# [12:06:35] ERROR: moving to the beginning of the next molecule
# [12:06:35] ERROR: Cannot process coordinates on line 29
# [12:06:35] ERROR: moving to the beginning of the next molecule
# [12:06:35] ERROR: Cannot process coordinates on line 52
# [12:06:35] ERROR: moving to the beginning of the next molecule
# [12:06:35] ERROR: Cannot process coordinates on line 75
# [12:06:35] ERROR: moving to the beginning of the next molecule
# [12:07:08] Explicit valence for atom # 15 C, 5, is greater than permitted
# [12:07:09] Explicit valence for atom # 7 O, 3, is greater than permitted
# [12:07:12] Explicit valence for atom # 17 N, 4, is greater than permitted
# [12:07:12] Explicit valence for atom # 27 O, 3, is greater than permitted
# [12:07:44] ERROR: Cannot process coordinates on line 11
# [12:18:27] ERROR: Cannot process coordinates on line 628
# [12:18:27] ERROR: moving to the beginning of the next molecule
# [12:18:40] Explicit valence for atom # 0 B, 5, is greater than permitted
# [12:18:46] Explicit valence for atom # 0 C, 5, is greater than permitted
# [12:18:47] Explicit valence for atom # 15 C, 5, is greater than permitted
# [12:19:11] Explicit valence for atom # 0 B, 5, is greater than permitted
# [12:19:14] Explicit valence for atom # 25 N, 4, is greater than permitted
# [12:19:47] Explicit valence for atom # 2 N, 4, is greater than permitted
# [12:19:58] ERROR: Cannot process coordinates on line 16
# [12:19:58] ERROR: moving to the beginning of the next molecule
# [12:20:15] Explicit valence for atom # 19 N, 4, is greater than permitted
# [12:20:34] Explicit valence for atom # 0 Cl, 2, is greater than permitted
# [12:20:36] Explicit valence for atom # 44 B, 4, is greater than permitted
# [12:20:48] Explicit valence for atom # 55 B, 4, is greater than permitted
# [12:20:53] Explicit valence for atom # 9 B, 4, is greater than permitted
# [12:21:00] Explicit valence for atom # 0 B, 4, is greater than permitted
# [12:21:05] ERROR: Cannot process coordinates on line 5
# [12:21:05] ERROR: moving to the beginning of the next molecule
# [12:21:26] Explicit valence for atom # 4 N, 4, is greater than permitted
# [12:21:30] Explicit valence for atom # 0 B, 5, is greater than permitted
# ---------------------------------------------------------------------------
# TimeoutExpired                            Traceback (most recent call last)
# Cell In[4], line 17
#      15 if mol is not None:
#      16     molecule_name = mol.GetProp('_Name')
# ---> 17     replacement_v1("in.mol", "out.sdf", "F", "H")
#      19     if os.path.exists('out.sdf') == True:
#      20         inf = open('out.sdf', 'rb')
#
# Cell In[3], line 12, in replacement_v1(f1, f2, before, after)
#      10 args = shlex.split(cmd)
#      11 p = subprocess.Popen(args)
# ---> 12 result = p.communicate(timeout=5)[0]
#
# File ~\anaconda3\envs\my-rdkit-env\Lib\subprocess.py:1228, in Popen.communicate(self, input, timeout)
#    1225     finally:
#    1226         self._communication_started = True
# -> 1228     sts = self.wait(timeout=self._remaining_time(endtime))
#    1230 return (stdout, stderr)
#
# File ~\anaconda3\envs\my-rdkit-env\Lib\subprocess.py:1264, in Popen.wait(self, timeout)
#    1262     endtime = _time() + timeout
#    1263 try:
# -> 1264     return self._wait(timeout=timeout)
#    1265 except KeyboardInterrupt:
#    1266     # https://bugs.python.org/issue25942
#    1267     # The first keyboard interrupt waits briefly for the child to
#    1268     # exit under the common assumption that it also received the ^C
#    1269     # generated SIGINT and will exit rapidly.
#    1270     if timeout is not None:
#
# File ~\anaconda3\envs\my-rdkit-env\Lib\subprocess.py:1591, in Popen._wait(self, timeout)
#    1588     result = _winapi.WaitForSingleObject(self._handle,
#    1589                                          timeout_millis)
#    1590     if result == _winapi.WAIT_TIMEOUT:
# -> 1591         raise TimeoutExpired(self.args, timeout)
#    1592     self.returncode = _winapi.GetExitCodeProcess(self._handle)
#    1593 return self.returncode
#
# TimeoutExpired: Command '['replacement', '-i', 'in.mol', '-o', 'out.sdf', '-before', 'F', '-after', 'H', '-all_atoms']' timed out after 5.0 seconds

# %% [markdown]
# Create txt file with smiles and parent molecules IDs:

# %%
file = open("F_H_1.smiles", "a")
for smi in SMILES_cont:
    name = smi[1]
    for ssmi in smi[0]:
        file.writelines(ssmi + "  " + name + "\n")
file.close()
